# %%
import pandas as pd

# %%
excel_file = 'c:\\development\\newDaiKo.xlsx'
df1 = pd.read_excel(excel_file)

# %%
import matplotlib.pyplot as plt

boxplotNew1 = df1.boxplot(by = 'SIDE WRT NORTH BOUND')

# %%
boxplotNew2 = df1.boxplot(by = 'Percentage loss')

# %%
boxplotNew2 = df1.boxplot()

# %%
excel_file = 'c:\\development\\newDaiKo.xlsx'
df = pd.read_excel(excel_file, sheet_name = 0)
df.shape
# Out:
# (348, 23)

# %%
df.head
# Out:
# <bound method NDFrame.head of            SFN  MILE MARKER         Int No. of Column Unnamed: 4 Unnamed: 5  \
# 0          NaN          NaN         NaN            rt        lft       cent
# 1    2102498.0  DEL-71-1307        CR34             4          4          4
# 2    2102498.0  DEL-71-1307        CR34           NaN        NaN        NaN
# 3    2102498.0  DEL-71-1307        CR34           NaN        NaN        NaN
# 4    2102498.0  DEL-71-1307        CR34           NaN        NaN        NaN
# 5    2102498.0  DEL-71-1307        CR34           NaN        NaN        NaN
# 6    2102498.0  DEL-71-1307        CR34           NaN        NaN        NaN
# 7    2102498.0  DEL-71-1307        CR34           NaN        NaN        NaN
# 8    2102498.0  DEL-71-1307        CR34           NaN        NaN        NaN
# 9    2102498.0  DEL-71-1307        CR34           NaN        NaN        NaN
# 10   2102498.0  DEL-71-1307        CR34           NaN        NaN        NaN
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of            SFN  MILE MARKER         Int No. of Column Unnamed: 4 Unnamed: 5  \
# 0          NaN          NaN         NaN            rt        lft       cent
# 1    2102498.0  DEL-71-1307        CR34             4          4          4
# 2    2102498.0  DEL-71-1307        CR34           NaN        NaN        NaN
# 3    2102498.0  DEL-71-1307        CR34           NaN        NaN        NaN
# 4    2102498.0  DEL-71-1307        CR34           NaN        NaN        NaN
# 5    2102498.0  DEL-71-1307        CR34           NaN        NaN        NaN
# 6    2102498.0  DEL-71-1307        CR34           NaN        NaN        NaN
# 7    2102498.0  DEL-71-1307        CR34           NaN        NaN        NaN
# 8    2102498.0  DEL-71-1307        CR34           NaN        NaN        NaN
# 9    2102498.0  DEL-71-1307        CR34           NaN        NaN        NaN
# 10   2102498.0  DEL-71-1307        CR34           NaN        NaN        NaN
# ...
